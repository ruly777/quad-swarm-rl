# %%
print("Hello World")
# Out:
# Hello World

# %%
1+2
# Out:
# 3

# %%
import gym
import torch 
import numpy
print('Все пакеты успешно установлены!')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import gym
#       2 import torch
#       3 import numpy
#
# ModuleNotFoundError: No module named 'gym'

# %%
try:
    import pyglet
    print("Pyglet version:", pyglet.version)
    
    window = pyglet.window.Window()
    print("Window created successfully")
except Exception as e:
    print("Error:", e)
# Out:
# Pyglet version: 1.5.23
# Error: Canvas must be an instance of XlibCanvas <class 'pyglet.canvas.xlib.XlibCanvas'>

# %%
import pyglet
window = pyglet.window.Window(width=200, height=200)
pyglet.app.run()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 2
#       1 import pyglet
# ----> 2 window = pyglet.window.Window(width=200, height=200)
#       3 pyglet.app.run()
#
# File ~/miniconda3/envs/swarm-rlc/lib/python3.11/site-packages/pyglet/window/xlib/__init__.py:171, in __init__(self, *args, **kwargs)
#     169 global _can_detect_autorepeat  # noqa: PLW0603
#     170 if _can_detect_autorepeat is None:
# --> 171     supported_rtrn = c_int()
#     172     _can_detect_autorepeat = XkbSetDetectableAutoRepeat(self.display._display, c_int(1),  # noqa: SLF001
#     173                                                         byref(supported_rtrn))
#     174 if _can_detect_autorepeat:
#
# ...

# %%
import os
os.environ['DISPLAY'] = '192.168.1.178:0.0'  # Your Windows IP address

# %%
import os
# Установка переменных окружения до импорта pyglet
os.environ['DISPLAY'] = '192.168.1.178:0.0'  # Ваш IP из Windows
os.environ['LIBGL_ALWAYS_INDIRECT'] = '1'
os.environ['MESA_GL_VERSION_OVERRIDE'] = '3.3'

# %%
import pyglet
from pyglet.gl import *
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 import pyglet
# ----> 2 from pyglet.gl import *
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/gl/__init__.py:232
#     229 if not _is_pyglet_doc_run and 'pyglet.window' not in _sys.modules and _pyglet.options['shadow_window']:
#     230     # trickery is for circular import
#     231     _pyglet.gl = _sys.modules[__name__]
# --> 232     import pyglet.window
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/window/__init__.py:1918
#    1916 if not _is_pyglet_doc_run:
#    1917     pyglet.window = sys.modules[__name__]
# -> 1918     gl._create_shadow_window()
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/gl/__init__.py:206, in _create_shadow_window()
#     203     return
#     205 from pyglet.window import Window
# ...

# %%
from pyglet.window import Window
# Out:
# ---------------------------------------------------------------------------
# NoSuchDisplayException                    Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pyglet.window import Window
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/window/__init__.py:1918
#    1916 if not _is_pyglet_doc_run:
#    1917     pyglet.window = sys.modules[__name__]
# -> 1918     gl._create_shadow_window()
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/gl/__init__.py:206, in _create_shadow_window()
#     203     return
#     205 from pyglet.window import Window
# --> 206 _shadow_window = Window(width=1, height=1, visible=False)
#     207 _shadow_window.switch_to()
#     209 from pyglet import app
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/window/xlib/__init__.py:171, in XlibWindow.__init__(self, *args, **kwargs)
#     168         else:
#     169             self._event_handlers[message] = func
# ...

# %%
import pyglet
window = pyglet.window.Window()
pyglet.app.run()
# Out:
# ---------------------------------------------------------------------------
# NoSuchDisplayException                    Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pyglet
# ----> 2 window = pyglet.window.Window()
#       3 pyglet.app.run()
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/window/xlib/__init__.py:171, in XlibWindow.__init__(self, *args, **kwargs)
#     168         else:
#     169             self._event_handlers[message] = func
# --> 171 super(XlibWindow, self).__init__(*args, **kwargs)
#     173 global _can_detect_autorepeat
#     174 if _can_detect_autorepeat is None:
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/window/__init__.py:590, in BaseWindow.__init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, file_drops, display, screen, config, context, mode)
#     587 self._event_queue = []
#     589 if not display:
# ...

# %%
# !pip show pyglet
# Out:
# Name: pyglet
# Version: 1.5.23
# Summary: Cross-platform windowing and multimedia library
# Home-page: http://pyglet.readthedocs.org/en/latest/
# Author: Alex Holkner
# Author-email: Alex.Holkner@gmail.com
# License: BSD
# Location: /home/ruly777/anaconda3/envs/swarm-rl/lib/python3.11/site-packages
# Requires:
# Required-by: sample-factory, swarm_rl

# %%
import pyglet

# %%
window = pyglet.window.Window()
pyglet.app.run()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 window = pyglet.window.Window()
#       2 pyglet.app.run()
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/window/xlib/__init__.py:171, in XlibWindow.__init__(self, *args, **kwargs)
#     168         else:
#     169             self._event_handlers[message] = func
# --> 171 super(XlibWindow, self).__init__(*args, **kwargs)
#     173 global _can_detect_autorepeat
#     174 if _can_detect_autorepeat is None:
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/window/__init__.py:600, in BaseWindow.__init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, file_drops, display, screen, config, context, mode)
#     596 for template_config in [gl.Config(double_buffer=True, depth_size=24),
# ...

# %%
import pyglet
from pyglet.gl import *

window = pyglet.window.Window(width=400, height=400)

@window.event
def on_draw():
    window.clear()
    
pyglet.app.run()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 import pyglet
#       2 from pyglet.gl import *
# ----> 4 window = pyglet.window.Window(width=400, height=400)
#       6 @window.event
#       7 def on_draw():
#       8     window.clear()
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/window/xlib/__init__.py:171, in XlibWindow.__init__(self, *args, **kwargs)
#     168         else:
#     169             self._event_handlers[message] = func
# --> 171 super(XlibWindow, self).__init__(*args, **kwargs)
#     173 global _can_detect_autorepeat
#     174 if _can_detect_autorepeat is None:
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/window/__init__.py:600, in BaseWindow.__init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, file_drops, display, screen, config, context, mode)
# ...

# %%
window = pyglet.window.Window(
    width=800,          # ширина окна
    height=600,         # высота окна
    caption='My Game',  # заголовок окна
    resizable=True,     # можно ли изменять размер
    vsync=True          # вертикальная синхронизация
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 window = pyglet.window.Window(
#       2     width=800,          # ширина окна
#       3     height=600,         # высота окна
#       4     caption='My Game',  # заголовок окна
#       5     resizable=True,     # можно ли изменять размер
#       6     vsync=True          # вертикальная синхронизация
#       7 )
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/window/xlib/__init__.py:171, in XlibWindow.__init__(self, *args, **kwargs)
#     168         else:
#     169             self._event_handlers[message] = func
# --> 171 super(XlibWindow, self).__init__(*args, **kwargs)
#     173 global _can_detect_autorepeat
#     174 if _can_detect_autorepeat is None:
#
# ...

# %%
import os
import pyglet
from pyglet.gl import *
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 import os
#       2 import pyglet
# ----> 3 from pyglet.gl import *
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/gl/__init__.py:232
#     229 if not _is_pyglet_doc_run and 'pyglet.window' not in _sys.modules and _pyglet.options['shadow_window']:
#     230     # trickery is for circular import
#     231     _pyglet.gl = _sys.modules[__name__]
# --> 232     import pyglet.window
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/window/__init__.py:1918
#    1916 if not _is_pyglet_doc_run:
#    1917     pyglet.window = sys.modules[__name__]
# -> 1918     gl._create_shadow_window()
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/gl/__init__.py:206, in _create_shadow_window()
#     203     return
#     205 from pyglet.window import Window
# ...

# %%
import pyglet
from pyglet.gl import *

# Используем более простую конфигурацию
config = pyglet.gl.Config(
    double_buffer=True,
    depth_size=24,
    major_version=3,
    minor_version=3
)

# Установим display перед созданием окна
display = pyglet.canvas.Display()
screen = display.get_default_screen()
window = pyglet.window.Window(
    config=config,
    screen=screen,
    width=800,
    height=600
)

@window.event
def on_draw():
    window.clear()

pyglet.app.run()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 15
#      13 display = pyglet.canvas.Display()
#      14 screen = display.get_default_screen()
# ---> 15 window = pyglet.window.Window(
#      16     config=config,
#      17     screen=screen,
#      18     width=800,
#      19     height=600
#      20 )
#      22 @window.event
#      23 def on_draw():
#      24     window.clear()
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/window/xlib/__init__.py:171, in XlibWindow.__init__(self, *args, **kwargs)
#     168         else:
#     169             self._event_handlers[message] = func
# --> 171 super(XlibWindow, self).__init__(*args, **kwargs)
#     173 global _can_detect_autorepeat
#     174 if _can_detect_autorepeat is None:
#
# ...

# %%
import os
# Set environment variables before importing pyglet
os.environ['DISPLAY'] = '192.168.1.178:0.0'  # Your Windows IP
os.environ['LIBGL_ALWAYS_INDIRECT'] = '1'
os.environ['MESA_GL_VERSION_OVERRIDE'] = '3.3'

# Now import pyglet
import pyglet
from pyglet.gl import *
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 9
#       7 # Now import pyglet
#       8 import pyglet
# ----> 9 from pyglet.gl import *
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/gl/__init__.py:232
#     229 if not _is_pyglet_doc_run and 'pyglet.window' not in _sys.modules and _pyglet.options['shadow_window']:
#     230     # trickery is for circular import
#     231     _pyglet.gl = _sys.modules[__name__]
# --> 232     import pyglet.window
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/window/__init__.py:1918
#    1916 if not _is_pyglet_doc_run:
#    1917     pyglet.window = sys.modules[__name__]
# -> 1918     gl._create_shadow_window()
#
# File ~/anaconda3/envs/swarm-rl/lib/python3.11/site-packages/pyglet/gl/__init__.py:206, in _create_shadow_window()
#     203     return
# ...

# %%
import ctypes
from OpenGL.GL import *
from OpenGL.GLUT import *

def print_opengl_info():
    print('Vendor:', glGetString(GL_VENDOR).decode())
    print('Renderer:', glGetString(GL_RENDERER).decode())
    print('OpenGL Version:', glGetString(GL_VERSION).decode())
    print('Shader Version:', glGetString(GL_SHADING_LANGUAGE_VERSION).decode())

# Инициализация GLUT
glutInit()
glutCreateWindow(b'OpenGL Info')
print_opengl_info()
# Out:
# Не удалось запустить ядро, так как среда Python "swarm-rl (Python -1.-1.-1)" больше не доступна. Рассмотрите возможность выбрать другое ядро или обновить список сред Python.
